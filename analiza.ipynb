# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("archive (1)/PJME_hourly.csv",parse_dates=[0])
df.head()
# Out:
#              Datetime  PJME_MW
# 0 2002-12-31 01:00:00  26498.0
# 1 2002-12-31 02:00:00  25147.0
# 2 2002-12-31 03:00:00  24574.0
# 3 2002-12-31 04:00:00  24393.0
# 4 2002-12-31 05:00:00  24860.0

# %%
print(df.dtypes)
df.info()
# Out:
# Datetime    datetime64[us]
# PJME_MW            float64
# dtype: object
# <class 'pandas.DataFrame'>
# RangeIndex: 145366 entries, 0 to 145365
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   Datetime  145366 non-null  datetime64[us]
#  1   PJME_MW   145366 non-null  float64
# dtypes: datetime64[us](1), float64(1)
# memory usage: 2.2 MB

# %%
df = df.set_index("Datetime")

# %%
df.head()
# Out:
#                      PJME_MW
# Datetime
# 2002-12-31 01:00:00  26498.0
# 2002-12-31 02:00:00  25147.0
# 2002-12-31 03:00:00  24574.0
# 2002-12-31 04:00:00  24393.0
# 2002-12-31 05:00:00  24860.0

# %%
df.index.dtype
# Out:
# dtype('<M8[us]')

# %%
df.index.nunique()
# Out:
# 145362

# %%
df.index
# Out:
# DatetimeIndex(['2002-12-31 01:00:00', '2002-12-31 02:00:00',
#                '2002-12-31 03:00:00', '2002-12-31 04:00:00',
#                '2002-12-31 05:00:00', '2002-12-31 06:00:00',
#                '2002-12-31 07:00:00', '2002-12-31 08:00:00',
#                '2002-12-31 09:00:00', '2002-12-31 10:00:00',
#                ...
#                '2018-01-01 15:00:00', '2018-01-01 16:00:00',
#                '2018-01-01 17:00:00', '2018-01-01 18:00:00',
#                '2018-01-01 19:00:00', '2018-01-01 20:00:00',
#                '2018-01-01 21:00:00', '2018-01-01 22:00:00',
#                '2018-01-01 23:00:00', '2018-01-02 00:00:00'],
#               dtype='datetime64[us]', name='Datetime', length=145366, freq=None)

# %%
pd.date_range(start = "2002-12-31 01:00:00", end = "2018-01-02 00:00:00", freq="h")
# Out:
# DatetimeIndex(['2002-12-31 01:00:00', '2002-12-31 02:00:00',
#                '2002-12-31 03:00:00', '2002-12-31 04:00:00',
#                '2002-12-31 05:00:00', '2002-12-31 06:00:00',
#                '2002-12-31 07:00:00', '2002-12-31 08:00:00',
#                '2002-12-31 09:00:00', '2002-12-31 10:00:00',
#                ...
#                '2018-01-01 15:00:00', '2018-01-01 16:00:00',
#                '2018-01-01 17:00:00', '2018-01-01 18:00:00',
#                '2018-01-01 19:00:00', '2018-01-01 20:00:00',
#                '2018-01-01 21:00:00', '2018-01-01 22:00:00',
#                '2018-01-01 23:00:00', '2018-01-02 00:00:00'],
#               dtype='datetime64[us]', length=131544, freq='h')

# %%
df.index.is_monotonic_increasing
# Out:
# False

# %%
df.index.duplicated().sum()
# Out:
# np.int64(4)

# %%
df.index.to_series().diff().value_counts()
# Out:
# Datetime
# 0 days 01:00:00      139275
# -2 days +01:00:00      6040
# 0 days 02:00:00          29
# 729 days 01:00:00         8
# 728 days 01:00:00         7
# 0 days 00:00:00           4
# -2 days +02:00:00         1
# 577 days 01:00:00         1
# Name: count, dtype: int64

# %%
df.index.min()
# Out:
# Timestamp('2002-01-01 01:00:00')

# %%
df.index.max()
# Out:
# Timestamp('2018-08-03 00:00:00')

# %%
df.index.nunique()
# Out:
# 145362

# %%
df = df.sort_index()

# %%
duplikaty = df.index.duplicated(keep=False)
duplikaty1 = df.index.duplicated(keep='first')
duplikatylast = df.index.duplicated(keep='last')

# %%
duplikaty.sum()
# Out:
# np.int64(8)

# %%
len(duplikaty)
# Out:
# 145366

# %%
duplikatylast
# Out:
# array([False, False, False, ..., False, False, False], shape=(145366,))

# %%
df.loc[duplikaty].sort_index()
# Out:
#                      PJME_MW
# Datetime
# 2014-11-02 02:00:00  23755.0
# 2014-11-02 02:00:00  22935.0
# 2015-11-01 02:00:00  21567.0
# 2015-11-01 02:00:00  21171.0
# 2016-11-06 02:00:00  20795.0
# 2016-11-06 02:00:00  21692.0
# 2017-11-05 02:00:00  21236.0
# 2017-11-05 02:00:00  20666.0

# %%
roznica = df.index.to_series().diff()

# %%
roznica!=pd.Timedelta(hours=1)
# Out:
# Datetime
# 2002-01-01 01:00:00     True
# 2002-01-01 02:00:00    False
# 2002-01-01 03:00:00    False
# 2002-01-01 04:00:00    False
# 2002-01-01 05:00:00    False
#                        ...
# 2018-08-02 20:00:00    False
# 2018-08-02 21:00:00    False
# 2018-08-02 22:00:00    False
# 2018-08-02 23:00:00    False
# 2018-08-03 00:00:00    False
# Name: Datetime, Length: 145366, dtype: bool

# %%
roznica[roznica > pd.Timedelta(hours=1)]
# Out:
# Datetime
# 2002-04-07 04:00:00   0 days 02:00:00
# 2002-10-27 03:00:00   0 days 02:00:00
# 2003-04-06 04:00:00   0 days 02:00:00
# 2003-10-26 03:00:00   0 days 02:00:00
# 2004-04-04 04:00:00   0 days 02:00:00
# 2004-10-31 03:00:00   0 days 02:00:00
# 2005-04-03 04:00:00   0 days 02:00:00
# 2005-10-30 03:00:00   0 days 02:00:00
# 2006-04-02 04:00:00   0 days 02:00:00
# 2006-10-29 03:00:00   0 days 02:00:00
# 2007-03-11 04:00:00   0 days 02:00:00
# 2007-11-04 03:00:00   0 days 02:00:00
# 2008-03-09 04:00:00   0 days 02:00:00
# 2008-11-02 03:00:00   0 days 02:00:00
# 2009-03-08 04:00:00   0 days 02:00:00
# 2009-11-01 03:00:00   0 days 02:00:00
# 2010-03-14 04:00:00   0 days 02:00:00
# 2010-11-07 03:00:00   0 days 02:00:00
# 2010-12-10 01:00:00   0 days 02:00:00
# 2011-03-13 04:00:00   0 days 02:00:00
# 2011-11-06 03:00:00   0 days 02:00:00
# 2012-03-11 04:00:00   0 days 02:00:00
# 2012-11-04 03:00:00   0 days 02:00:00
# 2013-03-10 04:00:00   0 days 02:00:00
# ...

# %%
pd.date_range(start=df.index.min(), end=df.index.max(), freq="h")
# Out:
# DatetimeIndex(['2002-01-01 01:00:00', '2002-01-01 02:00:00',
#                '2002-01-01 03:00:00', '2002-01-01 04:00:00',
#                '2002-01-01 05:00:00', '2002-01-01 06:00:00',
#                '2002-01-01 07:00:00', '2002-01-01 08:00:00',
#                '2002-01-01 09:00:00', '2002-01-01 10:00:00',
#                ...
#                '2018-08-02 15:00:00', '2018-08-02 16:00:00',
#                '2018-08-02 17:00:00', '2018-08-02 18:00:00',
#                '2018-08-02 19:00:00', '2018-08-02 20:00:00',
#                '2018-08-02 21:00:00', '2018-08-02 22:00:00',
#                '2018-08-02 23:00:00', '2018-08-03 00:00:00'],
#               dtype='datetime64[us]', length=145392, freq='h')

# %%
duplikaty = df.index.duplicated(keep="first")
~duplikaty
# Out:
# array([ True,  True,  True, ...,  True,  True,  True], shape=(145366,))

# %%
df = df[~duplikaty]
df.shape
# Out:
# (145362, 1)

# %%
oś = pd.date_range(start=df.index.min(), end=df.index.max(), freq="h")
df = df.reindex(oś)

# %%
df.isna().sum()
# Out:
# PJME_MW    30
# dtype: int64

# %%
df = df.interpolate(method="time")
df.loc["2010-12-09 23:00":"2010-12-10 03:00"]
# Out:
#                      PJME_MW
# 2010-12-09 23:00:00  37729.0
# 2010-12-10 00:00:00  35446.0
# 2010-12-10 01:00:00  33163.0
# 2010-12-10 02:00:00  32323.0
# 2010-12-10 03:00:00  32016.0

# %%
df.shape
# Out:
# (145392, 1)
